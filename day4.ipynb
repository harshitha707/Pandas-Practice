# %%
import pandas as pd
df = pd.read_csv("weather_by_cities.csv")
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
df.pivot(index='day', columns='city')
# Out:
#          temperature                windspeed                 event           \
# city          mumbai new york paris    mumbai new york paris mumbai new york
# day
# 1/1/2017          90       32    45         5        6    20  Sunny     Rain
# 1/2/2017          85       36    50        12        7    13    Fog    Sunny
# 1/3/2017          87       28    54        15       12     8    Fog     Snow
# 1/4/2017          92       33    42         5        7    10   Rain    Sunny
#
#
# city       paris
# day
# 1/1/2017   Sunny
# 1/2/2017  Cloudy
# 1/3/2017  Cloudy
# 1/4/2017  Cloudy

# %%
df = pd.read_csv("weather.csv")
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df.pivot_table(index="city", columns="date")
# Out:
#          humidity                   temperature
# date     5/1/2017 5/2/2017 5/3/2017    5/1/2017 5/2/2017 5/3/2017
# city
# beijing      26.0     30.0     35.0        80.0     77.0     79.0
# mumbai       80.0     83.0     85.0        75.0     78.0     82.0
# new york     56.0     58.0     60.0        65.0     66.0     68.0

# %%
df.pivot_table(index="city", columns="date", aggfunc='count')
# Out:
#          humidity                   temperature
# date     5/1/2017 5/2/2017 5/3/2017    5/1/2017 5/2/2017 5/3/2017
# city
# beijing         1        1        1           1        1        1
# mumbai          1        1        1           1        1        1
# new york        1        1        1           1        1        1

# %%
df2 = pd.read_csv("weather(1).csv")
df2
# Out:
#          day  chicago  chennai  berlin
# 0     Monday       32       75      41
# 1    Tuesday       30       77      43
# 2  Wednesday       28       75      45
# 3   Thursday       22       82      38
# 4     Friday       30       83      30
# 5   Saturday       20       81      45
# 6     Sunday       25       77      47

# %%
df3 = pd.melt(df2, id_vars=["day"])
df3
# Out:
#           day variable  value
# 0      Monday  chicago     32
# 1     Tuesday  chicago     30
# 2   Wednesday  chicago     28
# 3    Thursday  chicago     22
# 4      Friday  chicago     30
# 5    Saturday  chicago     20
# 6      Sunday  chicago     25
# 7      Monday  chennai     75
# 8     Tuesday  chennai     77
# 9   Wednesday  chennai     75
# 10   Thursday  chennai     82
# 11     Friday  chennai     83
# 12   Saturday  chennai     81
# 13     Sunday  chennai     77
# 14     Monday   berlin     41
# 15    Tuesday   berlin     43
# 16  Wednesday   berlin     45
# 17   Thursday   berlin     38
# 18     Friday   berlin     30
# 19   Saturday   berlin     45
# 20     Sunday   berlin     47

# %%
df3 = pd.melt(df2, id_vars=["day"])
df3[df3["variable"] == "chicago"]
# Out:
#          day variable  value
# 0     Monday  chicago     32
# 1    Tuesday  chicago     30
# 2  Wednesday  chicago     28
# 3   Thursday  chicago     22
# 4     Friday  chicago     30
# 5   Saturday  chicago     20
# 6     Sunday  chicago     25

# %%
df3 = pd.melt(df2, id_vars=["day"], var_name="city", value_name="temp")
df3
# Out:
#           day     city  temp
# 0      Monday  chicago    32
# 1     Tuesday  chicago    30
# 2   Wednesday  chicago    28
# 3    Thursday  chicago    22
# 4      Friday  chicago    30
# 5    Saturday  chicago    20
# 6      Sunday  chicago    25
# 7      Monday  chennai    75
# 8     Tuesday  chennai    77
# 9   Wednesday  chennai    75
# 10   Thursday  chennai    82
# 11     Friday  chennai    83
# 12   Saturday  chennai    81
# 13     Sunday  chennai    77
# 14     Monday   berlin    41
# 15    Tuesday   berlin    43
# 16  Wednesday   berlin    45
# 17   Thursday   berlin    38
# 18     Friday   berlin    30
# 19   Saturday   berlin    45
# 20     Sunday   berlin    47

# %%
df5 = pd.read_excel("stocks.xlsx", header=[0,1])
df5
# Out:
#   Unnamed: 0_level_0    Price                  Price to earnings ratio (P/E)  \
#              Company Facebook Google Microsoft                      Facebook
# 0         2017-06-05      155    955        66                         37.10
# 1         2017-06-06      150    987        69                         36.98
# 2         2017-06-07      153    963        62                         36.78
# 3         2017-06-08      155   1000        61                         36.11
# 4         2017-06-09      156   1012        66                         37.07
#
#
#   Google Microsoft
# 0   32.0     30.31
# 1   31.3     30.56
# 2   31.7     30.46
# 3   31.2     30.11
# 4   30.0     31.00

# %%
dfstack = df5.stack(level=1, dropna=True)
dfstack
# Out:
# C:\Users\bandi\AppData\Local\Temp\ipykernel_7536\667977255.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   dfstack = df5.stack(level=1, dropna=True)
#             Unnamed: 0_level_0   Price  Price to earnings ratio (P/E)
# 0 Company           2017-06-05     NaN                            NaN
#   Facebook                 NaT   155.0                          37.10
#   Google                   NaT   955.0                          32.00
#   Microsoft                NaT    66.0                          30.31
# 1 Company           2017-06-06     NaN                            NaN
#   Facebook                 NaT   150.0                          36.98
#   Google                   NaT   987.0                          31.30
# ...

# %%
dfstack.unstack()
# Out:
#   Unnamed: 0_level_0                             Price                   \
#              Company Facebook Google Microsoft Company Facebook  Google
# 0         2017-06-05      NaT    NaT       NaT     NaN    155.0   955.0
# 1         2017-06-06      NaT    NaT       NaT     NaN    150.0   987.0
# 2         2017-06-07      NaT    NaT       NaT     NaN    153.0   963.0
# 3         2017-06-08      NaT    NaT       NaT     NaN    155.0  1000.0
# 4         2017-06-09      NaT    NaT       NaT     NaN    156.0  1012.0
#
#             Price to earnings ratio (P/E)
#   Microsoft                       Company Facebook Google Microsoft
# 0      66.0                           NaN    37.10   32.0     30.31
# 1      69.0                           NaN    36.98   31.3     30.56
# 2      62.0                           NaN    36.78   31.7     30.46
# 3      61.0                           NaN    36.11   31.2     30.11
# 4      66.0                           NaN    37.07   30.0     31.00

# %%
df6 = pd.read_excel("stocks_3_levels.xlsx")
df6
# Out:
#   Unnamed: 0 Price Ratios Unnamed: 2 Unnamed: 3  \
# 0        NaN        Price        NaN        NaN
# 1    Company     Facebook     Google  Microsoft
# 2    Q1 2016          155        955         66
# 3    Q2 2016          150        987         69
# 4    Q3 2016          153        963         62
# 5    Q4 2016          155       1000         61
# 6    Q1 2017          156       1012         66
#
#                       Unnamed: 4 Unnamed: 5 Unnamed: 6 Income Statement  \
# 0  Price to earnings ratio (P/E)        NaN        NaN        Net Sales
# 1                       Facebook     Google  Microsoft         Facebook
# 2                           37.1         32      30.31              2.6
# 3                          36.98       31.3      30.56              3.1
# 4                          36.78       31.7      30.46              4.3
# 5                          36.11       31.2      30.11              6.7
# 6                          37.07         30         31              8.1
# ...

# %%
df6.stack(level=0)
# Out:
# 0  Price Ratios                                Price
#    Unnamed: 4          Price to earnings ratio (P/E)
#    Income Statement                        Net Sales
#    Unnamed: 10                            Net Profit
# 1  Unnamed: 0                                Company
#                                    ...
# 6  Unnamed: 8                                     31
#    Unnamed: 9                                  22.34
#    Unnamed: 10                                  2.03
#    Unnamed: 11                                   6.4
#    Unnamed: 12                                  6.09
# Length: 82, dtype: object
